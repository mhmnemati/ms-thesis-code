# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
x = np.random.rand(3000)

# %%
freqs, times, Zxx = sp.signal.stft(x, fs=100, noverlap=0)

# %%
times.shape, freqs.shape, Zxx.shape
# Out:
# ((25,), (129,), (129, 25))

# %%
times
# Out:
# array([ 0.  ,  1.28,  2.56,  3.84,  5.12,  6.4 ,  7.68,  8.96, 10.24,
#        11.52, 12.8 , 14.08, 15.36, 16.64, 17.92, 19.2 , 20.48, 21.76,
#        23.04, 24.32, 25.6 , 26.88, 28.16, 29.44, 30.72])

# %%
plt.figure(figsize=(10, 6))
plt.pcolormesh(times, freqs, np.abs(Zxx), shading="gouraud")
plt.show()
